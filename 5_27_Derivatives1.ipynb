# %% [markdown]
# <a href="https://colab.research.google.com/github/esineyildiz/deep-learning-mike-cohen/blob/main/5_27_Derivatives1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np


# sympy = symbolic math in python
import sympy as sym
import sympy.plotting.plot as symplot

# %%
# create symbolic variables in sympy
x = sym.symbols('x')

# create a function
fx = 2*x**2

# compute its derivative
df = sym.diff(fx,x)

# print them
print(fx)
print(df)
# Out:
# 2*x**2
# 4*x

# %%
# plot them
symplot(fx,(x,-4,4),title='The function')
plt.show()

symplot(df,(x,-4,4),title='Its derivative')
plt.show()

# %%
# repeat whith relu and sigmoid

# create symbolic funcs
relu = sym.Max(0,x)
sigmoid = 1/ (1+sym.exp(-x))

# graph the funcs
p = symplot(relu,(x,-4,4),title='ReLU',show=False,line_color='blue')
p.extend( symplot(sigmoid,(x,-4,4),label='Sigmoid',show=False,line_color='red'))
p.legend = True
p.title = 'The functions'
p.show()

# grapht their derivatives
p = symplot(sym.diff(relu),(x,-4,4),title='df(Relu)',show=False,line_color='blue')
p.extend( symplot(sym.diff(sigmoid),(x,-4,4),label='df(Sigmoid)',show=False,line_color='red'))
p.legend = True
p.title = 'The derivatives'
p.show()
